# %%
from functions import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset with 500 repititions 2 true 7 false

# %%
# Load in the results

# LASSO-SCNLS
results_scnls_500_reps_var_0_7 = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_SCNLS_LASSO_2_true_7_false_25_dmu_not_sorted_0_1_var_eta_0_05_CORR_False.csv', sep=';', index_col=0)
results_scnls_500_reps_var_0_1 = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_SCNLS_LASSO_2_true_7_false_25_dmu_not_sorted_0_7_var_eta_0_15_CORR_False.csv', sep=';', index_col=0)
results_scnls_500_reps_var_0_7_corr = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_SCNLS_LASSO_2_true_7_false_25_dmu_not_sorted_0_7_var_eta_0_09_CORR_True.csv', sep=';', index_col=0)
results_scnls_500_reps_var_0_1_corr = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_SCNLS_LASSO_2_true_7_false_25_dmu_not_sorted_0_1_var_eta_0_04_CORR_True.csv', sep=';', index_col=0)

# Regular LASSO
results_regular_lasso_500_reps_var_0_7 = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_regular_LASSO_2_true_7_false_25_dmu_not_sorted_0_7_var_eta_0_079_CORR_False.csv', sep=';', index_col=0)
results_regular_lasso_500_reps_var_0_1 = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_regular_LASSO_2_true_7_false_25_dmu_not_sorted_0_1_var_eta_0_01_CORR_False.csv', sep=';', index_col=0)
results_regular_lasso_500_reps_var_0_7_corr = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_regular_LASSO_2_true_7_false_25_dmu_not_sorted_0_7_var_eta_0_1_CORR_True.csv', sep=';', index_col=0)
results_regular_lasso_500_reps_var_0_1_corr = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_regular_LASSO_2_true_7_false_25_dmu_not_sorted_0_1_var_eta_0_016_CORR_True.csv', sep=';', index_col=0)

# PCA DEA
results_pca_dea_500_reps_var_0_7 = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_PCA_DEA_2_true_7_false_25_dmu_not_sorted_0_7_var_eta_0_CORR_False.csv', sep=';', index_col=0)
results_pca_dea_500_reps_var_0_1 = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_PCA_DEA_2_true_7_false_25_dmu_not_sorted_0_1_var_eta_0_CORR_False.csv', sep=';', index_col=0)
results_pca_dea_500_reps_var_0_7_corr = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_PCA_DEA_2_true_7_false_25_dmu_not_sorted_0_7_var_eta_0_CORR_True.csv', sep=';', index_col=0)
results_pca_dea_500_reps_var_0_1_corr = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_PCA_DEA_2_true_7_false_25_dmu_not_sorted_0_1_var_eta_0_CORR_True.csv', sep=';', index_col=0)

# Random selection
results_random = pd.read_csv('../Coding/Datasets_used_for_inference/1_results_random_2_true_7_false_25_dmu.csv', sep=';', index_col=0)


# Calculate the results
result_matrix = pd.DataFrame(columns=
    ['Average MSE', 'Average nr variables deleted', 'Average nr correct variables deleted', 
    'Average nr false variables deleted', 'Correct deletion ratio', 'False deletion ratio', 'Probability of selecting 2 true inputs', 
    'Probability of selecting at least 1 true input', 'Probability of selecting 0 true inputs'])

result_matrix.loc['SCNLS-LASSO, Variance = 0.7, Not correlated',:] = results_from_matrix(results_scnls_500_reps_var_0_7)
result_matrix.loc['SCNLS-LASSO, Variance = 0.1, Not correlated',:] = results_from_matrix(results_scnls_500_reps_var_0_1)
result_matrix.loc['SCNLS-LASSO, Variance = 0.7, Correlated',:] = results_from_matrix(results_scnls_500_reps_var_0_7_corr)
result_matrix.loc['SCNLS-LASSO, Variance = 0.1, Correlated',:] = results_from_matrix(results_scnls_500_reps_var_0_1_corr)

result_matrix.loc['Regular LASSO, Variance = 0.7, Not correlated',:] = results_from_matrix(results_regular_lasso_500_reps_var_0_7)
result_matrix.loc['Regular LASSO, Variance = 0.1, Not correlated',:] = results_from_matrix(results_regular_lasso_500_reps_var_0_1)
result_matrix.loc['Regular LASSO, Variance = 0.7, Correlated',:] = results_from_matrix(results_regular_lasso_500_reps_var_0_7_corr)
result_matrix.loc['Regular LASSO, Variance = 0.1, Correlated',:] = results_from_matrix(results_regular_lasso_500_reps_var_0_1_corr)

result_matrix.loc['PCA-DEA, Variance = 0.7, Not correlated',:] = results_from_matrix(results_pca_dea_500_reps_var_0_7)
result_matrix.loc['PCA-DEA, Variance = 0.1, Not correlated',:] = results_from_matrix(results_pca_dea_500_reps_var_0_1)
result_matrix.loc['PCA-DEA, Variance = 0.7, Correlated',:] = results_from_matrix(results_pca_dea_500_reps_var_0_7_corr)
result_matrix.loc['PCA-DEA, Variance = 0.1, Correlated',:] = results_from_matrix(results_pca_dea_500_reps_var_0_1_corr)

result_matrix.loc['Random selection',:] = results_from_matrix(results_random)

result_matrix = [['Average MSE', 'Average nr variables deleted',
       'Average nr false variables deleted', 'Correct deletion ratio',
       'False deletion ratio', 'Probability of selecting 2 true inputs',
       'Probability of selecting at least 1 true input',
       'Probability of selecting 0 true inputs']]
display(result_matrix)

result_matrix.to_latex(buf='file.tex', index=True, column_format='|c|c|c|c|c|c|c|c|c|',longtable=False, escape=False, encoding='utf-8')
# Out:
#                                               Average MSE  \
# SCNLS-LASSO, Variance = 0.7, Not correlated       0.00059
# SCNLS-LASSO, Variance = 0.1, Not correlated      0.031391
# SCNLS-LASSO, Variance = 0.7, Correlated          0.065414
# SCNLS-LASSO, Variance = 0.1, Correlated          0.001616
# Regular LASSO, Variance = 0.7, Not correlated    0.157315
# Regular LASSO, Variance = 0.1, Not correlated     0.00769
# Regular LASSO, Variance = 0.7, Correlated        0.167761
# Regular LASSO, Variance = 0.1, Correlated        0.013061
# PCA-DEA, Variance = 0.7, Not correlated          0.104486
# PCA-DEA, Variance = 0.1, Not correlated          0.006455
# PCA-DEA, Variance = 0.7, Correlated              0.111431
# PCA-DEA, Variance = 0.1, Correlated              0.001563
# Random selection                                      NaN
#
#                                               Average nr variables deleted  \
# ...

# %% [markdown]
# # Incremental analysis 30 repititions each

# %%
# LASSO-SCNLS
results_scnls_incr_var_0_7 = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_SCNLS_df_100_dmus_30_reps_eta_0_15_notsorted_var_0_7_CORR_False_non_alternating_ETAS.csv', sep=',', index_col=0))
results_scnls_incr_var_0_1 = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_SCNLS_df_100_dmus_30_reps_eta_0_05_notsorted_var_0_1_CORR_False_non_alternating_ETAS.csv', sep=',', index_col=0))
results_scnls_incr_var_0_7_corr = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_SCNLS_df_100_dmus_30_reps_eta_0_09_notsorted_var_0_7_CORR_True_non_alternating_ETAS.csv', sep=',', index_col=0))
results_scnls_incr_var_0_1_corr = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_SCNLS_df_100_dmus_30_reps_eta_0_04_notsorted_var_0_1_CORR_True_non_alternating_ETAS.csv', sep=',', index_col=0))


# Regular LASSO
results_regular_lasso_incr_var_0_7 = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_regular_LASSO_df_100_dmus_30_reps_eta_0_046_notsorted_var_0_7_CORR_False.csv', sep=',', index_col=0))
results_regular_lasso_incr_var_0_1 = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_regular_LASSO_df_100_dmus_30_reps_eta_0_01_notsorted_var_0_1_CORR_False.csv', sep=',', index_col=0))
results_regular_lasso_incr_var_0_7_corr = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_regular_LASSO_df_100_dmus_30_reps_eta_0_1_notsorted_var_0_7_CORR_True.csv', sep=',', index_col=0))
results_regular_lasso_incr_var_0_1_corr = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_regular_LASSO_df_100_dmus_30_reps_eta_0_01_notsorted_var_0_1_CORR_True.csv', sep=',', index_col=0))

# PCA-DEA
results_pca_dea_incr_var_0_7 = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_PCA_DEA_df_100_dmus_30_reps_eta_0_notsorted_var_0_7_CORR_False.csv', sep=',', index_col=0))
results_pca_dea_incr_var_0_1 = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_PCA_DEA_df_100_dmus_30_reps_eta_0_notsorted_var_0_1_CORR_False.csv', sep=',', index_col=0))
results_pca_dea_incr_var_0_7_corr = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_PCA_DEA_df_100_dmus_30_reps_eta_0_notsorted_var_0_7_CORR_True.csv', sep=',', index_col=0))
results_pca_dea_incr_var_0_1_corr = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_PCA_DEA_df_100_dmus_30_reps_eta_0_notsorted_var_0_1_CORR_True.csv', sep=',', index_col=0))

# Random selection
results_random_incr_var_0_7 = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_Random_df_100_dmus_30_reps_eta_0_notsorted_var_0_7_CORR_False.csv', sep=',', index_col=0))
results_random_incr_var_0_1 = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_Random_df_100_dmus_30_reps_eta_0_notsorted_var_0_1_CORR_False.csv', sep=',', index_col=0))
results_random_incr_var_0_7_corr = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_Random_df_100_dmus_30_reps_eta_0_notsorted_var_0_7_CORR_True.csv', sep=',', index_col=0))
results_random_incr_var_0_1_corr = retrieve_incremental_results(pd.read_csv('../Coding/Datasets_incremental_analysis/1_testresults_Random_df_100_dmus_30_reps_eta_0_notsorted_var_0_1_CORR_True.csv', sep=',', index_col=0))

# %%
# plot the results


# MSE Scores
fig_mse, ax = plt.subplots(2, 2, figsize=(12, 8))
ax[0,0].plot(results_scnls_incr_var_0_7['DMU'], results_scnls_incr_var_0_7['MSE'], label='SCNLS-LASSO')
ax[0,0].plot(results_regular_lasso_incr_var_0_7['DMU'], results_regular_lasso_incr_var_0_7['MSE'], label='LASSO')
ax[0,0].plot(results_pca_dea_incr_var_0_7['DMU'], results_pca_dea_incr_var_0_7['MSE'], label='PCA-DEA')
ax[0,0].plot(results_random_incr_var_0_7['DMU'], results_random_incr_var_0_7['MSE'], label='Random')
ax[0,0].set_title('MSE scores when Var(mu)=0.7, Uncorrelated inputs')
ax[0,0].legend()

ax[0,1].plot(results_scnls_incr_var_0_7_corr['DMU'], results_scnls_incr_var_0_7_corr['MSE'], label='SCNLS-LASSO')
ax[0,1].plot(results_regular_lasso_incr_var_0_7_corr['DMU'], results_regular_lasso_incr_var_0_7_corr['MSE'], label='LASSO')
ax[0,1].plot(results_pca_dea_incr_var_0_7_corr['DMU'], results_pca_dea_incr_var_0_7_corr['MSE'], label='PCA-DEA')
ax[0,1].plot(results_random_incr_var_0_7_corr['DMU'], results_random_incr_var_0_7_corr['MSE'], label='Random')
ax[0,1].set_title('MSE scores when Var(mu)=0.7, Correlated inputs')
ax[0,1].legend()

ax[1,0].plot(results_scnls_incr_var_0_1['DMU'], results_scnls_incr_var_0_1['MSE'], label='SCNLS-LASSO')
ax[1,0].plot(results_regular_lasso_incr_var_0_1['DMU'], results_regular_lasso_incr_var_0_1['MSE'], label='LASSO')
ax[1,0].plot(results_pca_dea_incr_var_0_1['DMU'], results_pca_dea_incr_var_0_1['MSE'], label='PCA-DEA')
ax[1,0].plot(results_random_incr_var_0_1['DMU'], results_random_incr_var_0_1['MSE'], label='Random')
ax[1,0].set_title('MSE scores when Var(mu)=0.1, uncorrelated')
ax[1,0].legend()

ax[1,1].plot(results_scnls_incr_var_0_1_corr['DMU'], results_scnls_incr_var_0_1_corr['MSE'], label='SCNLS-LASSO')
ax[1,1].plot(results_regular_lasso_incr_var_0_1_corr['DMU'], results_regular_lasso_incr_var_0_1_corr['MSE'], label='LASSO')
ax[1,1].plot(results_pca_dea_incr_var_0_1_corr['DMU'], results_pca_dea_incr_var_0_1_corr['MSE'], label='PCA-DEA')
ax[1,1].plot(results_random_incr_var_0_1_corr['DMU'], results_random_incr_var_0_1_corr['MSE'], label='Random')
ax[1,1].set_title('MSE scores when Var(mu)=0.1, uncorrelated')
ax[1,1].legend()
fig_mse.tight_layout()

# Nr variables deleted
fig_nr_vars, ax = plt.subplots(2, 2, figsize=(12, 8))
ax[0,0].plot(results_scnls_incr_var_0_7['DMU'], results_scnls_incr_var_0_7['nr_variables_deleted'], label='SCNLS-LASSO')
ax[0,0].plot(results_regular_lasso_incr_var_0_7['DMU'], results_regular_lasso_incr_var_0_7['nr_variables_deleted'], label='LASSO')
ax[0,0].plot(results_pca_dea_incr_var_0_7['DMU'], results_pca_dea_incr_var_0_7['nr_variables_deleted'], label='PCA-DEA')
ax[0,0].plot(results_random_incr_var_0_7['DMU'], results_random_incr_var_0_7['nr_variables_deleted'], label='Random')
ax[0,0].set_title('Nr variables deleted when Var(mu)=0.7, Uncorrelated inputs')
ax[0,0].legend()

ax[0,1].plot(results_scnls_incr_var_0_7_corr['DMU'], results_scnls_incr_var_0_7_corr['nr_variables_deleted'], label='SCNLS-LASSO')
ax[0,1].plot(results_regular_lasso_incr_var_0_7_corr['DMU'], results_regular_lasso_incr_var_0_7_corr['nr_variables_deleted'], label='LASSO')
ax[0,1].plot(results_pca_dea_incr_var_0_7_corr['DMU'], results_pca_dea_incr_var_0_7_corr['nr_variables_deleted'], label='PCA-DEA')
ax[0,1].plot(results_random_incr_var_0_7_corr['DMU'], results_random_incr_var_0_7_corr['nr_variables_deleted'], label='Random')
ax[0,1].set_title('Nr variables deleted when Var(mu)=0.7, Correlated inputs')
ax[0,1].legend()

ax[1,0].plot(results_scnls_incr_var_0_1['DMU'], results_scnls_incr_var_0_1['nr_variables_deleted'], label='SCNLS-LASSO')
ax[1,0].plot(results_regular_lasso_incr_var_0_1['DMU'], results_regular_lasso_incr_var_0_1['nr_variables_deleted'], label='LASSO')
ax[1,0].plot(results_pca_dea_incr_var_0_1['DMU'], results_pca_dea_incr_var_0_1['nr_variables_deleted'], label='PCA-DEA')
ax[1,0].plot(results_random_incr_var_0_1['DMU'], results_random_incr_var_0_1['nr_variables_deleted'], label='Random')
ax[1,0].set_title('Nr variables deleted when Var(mu)=0.1, uncorrelated')
ax[1,0].legend()

ax[1,1].plot(results_scnls_incr_var_0_1_corr['DMU'], results_scnls_incr_var_0_1_corr['nr_variables_deleted'], label='SCNLS-LASSO')
ax[1,1].plot(results_regular_lasso_incr_var_0_1_corr['DMU'], results_regular_lasso_incr_var_0_1_corr['nr_variables_deleted'], label='LASSO')
ax[1,1].plot(results_pca_dea_incr_var_0_1_corr['DMU'], results_pca_dea_incr_var_0_1_corr['nr_variables_deleted'], label='PCA-DEA')
ax[1,1].plot(results_random_incr_var_0_1_corr['DMU'], results_random_incr_var_0_1_corr['nr_variables_deleted'], label='Random')
ax[1,1].set_title('Nr variables deleted when Var(mu)=0.1, Correlated inputs')
ax[1,1].legend()
fig_nr_vars.tight_layout()

# False deletion ratio
fig_fdr, ax = plt.subplots(2, 2, figsize=(12, 8))
ax[0,0].plot(results_scnls_incr_var_0_7['DMU'], results_scnls_incr_var_0_7['false_deletion_ratio'], label='SCNLS-LASSO')
ax[0,0].plot(results_regular_lasso_incr_var_0_7['DMU'], results_regular_lasso_incr_var_0_7['false_deletion_ratio'], label='LASSO')
# ax[0,0].plot(results_pca_dea_incr_var_0_7['DMU'], results_pca_dea_incr_var_0_7['false_deletion_ratio'], label='PCA-DEA')
ax[0,0].plot(results_random_incr_var_0_7['DMU'], results_random_incr_var_0_7['false_deletion_ratio'], label='Random')
ax[0,0].set_title('False deletion ratio when Var(mu)=0.7, Uncorrelated inputs')
ax[0,0].legend()

ax[0,1].plot(results_scnls_incr_var_0_7_corr['DMU'], results_scnls_incr_var_0_7_corr['false_deletion_ratio'], label='SCNLS-LASSO')
ax[0,1].plot(results_regular_lasso_incr_var_0_7_corr['DMU'], results_regular_lasso_incr_var_0_7_corr['false_deletion_ratio'], label='LASSO')
# ax[0,1].plot(results_pca_dea_incr_var_0_7_corr['DMU'], results_pca_dea_incr_var_0_7_corr['false_deletion_ratio'], label='PCA-DEA')
ax[0,1].plot(results_random_incr_var_0_7_corr['DMU'], results_random_incr_var_0_7_corr['false_deletion_ratio'], label='Random')
ax[0,1].set_title('False deletion ratio when Var(mu)=0.7, Correlated inputs')
ax[0,1].legend()

ax[1,0].plot(results_scnls_incr_var_0_1['DMU'], results_scnls_incr_var_0_1['false_deletion_ratio'], label='SCNLS-LASSO')
ax[1,0].plot(results_regular_lasso_incr_var_0_1['DMU'], results_regular_lasso_incr_var_0_1['false_deletion_ratio'], label='LASSO')
# ax[1,0].plot(results_pca_dea_incr_var_0_1['DMU'], results_pca_dea_incr_var_0_1['false_deletion_ratio'], label='PCA-DEA')
ax[1,0].plot(results_random_incr_var_0_1['DMU'], results_random_incr_var_0_1['false_deletion_ratio'], label='Random')
ax[1,0].set_title('False deletion ratio when Var(mu)=0.1, Uncorrelated inputs')
ax[1,0].legend()

ax[1,1].plot(results_scnls_incr_var_0_1_corr['DMU'], results_scnls_incr_var_0_1_corr['false_deletion_ratio'], label='SCNLS-LASSO')
ax[1,1].plot(results_regular_lasso_incr_var_0_1_corr['DMU'], results_regular_lasso_incr_var_0_1_corr['false_deletion_ratio'], label='LASSO')
# ax[1,1].plot(results_pca_dea_incr_var_0_1_corr['DMU'], results_pca_dea_incr_var_0_1_corr['false_deletion_ratio'], label='PCA-DEA')
ax[1,1].plot(results_random_incr_var_0_1_corr['DMU'], results_random_incr_var_0_1_corr['false_deletion_ratio'], label='Random')
ax[1,1].set_title('False deletion ratio when Var(mu)=0.1, Correlated inputs')
ax[1,1].legend()
fig_fdr.tight_layout()
